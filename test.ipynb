# %%
import pandas as pd
import pandas as pd
from streamlit_elements import elements, dashboard, mui, nivo
import streamlit as st
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 3
#       1 import pandas as pd
#       2 import pandas as pd
# ----> 3 from streamlit_elements import elements, dashboard, mui, nivo
#       4 import streamlit as st
#
# ModuleNotFoundError: No module named 'streamlit_elements'

# %%
df = pd.read_csv('shipments.csv', encoding='latin-1', decimal='.', sep=';')

# %%
data
# Out:
#       shipment_number                   Customer        Date        Origin  \
# 0                   1                CarterGroup  2024-06-24        Muscat
# 1                   2   Henderson,BoydandShelton  2024-07-24   Johanesburg
# 2                   3                   ShortLtd  2023-09-03      New York
# 3                   4                 ElliottLtd  2023-10-21         Tokyo
# 4                   5   Waters,ReynoldsandHoward  2023-04-10     Barcelona
# ...               ...                        ...         ...           ...
# 1195             1196       OmniTech Fabrication  2023-08-20   Los Angeles
# 1196             1197  StellarWave Manufacturing  2024-07-21       Chicago
# 1197             1198        QuantumEcho Foundry  2023-11-17       Chicago
# 1198             1199             Simmons-Turner  2023-07-04  Buenos Aires
# 1199             1200    Klein,RobinsonandMiller  2023-09-29       Chicago
#
#      Destination  Weight (kgs)  Volume (cubic meters)  Invoiced Value  \
# 0      Barcelona          1565                   2.44        10907.36
# 1      Barcelona          3359                   1.89         9847.63
# 2      Barcelona          1688                   1.40         1395.93
# 3      Barcelona           190                   2.31         8389.96
# 4     Casablanca           437                   1.13        10392.05
# ...          ...           ...                    ...             ...
# 1195   Barcelona          2603                   6.92         5986.70
# 1196   Barcelona           586                   6.23         8898.89
# 1197   Barcelona          3712                   6.61         4618.31
# 1198   Barcelona          2258                   5.92         1341.78
# 1199   Barcelona           417                   3.03         4373.01
#
#       Cost Value  Markup  Department           sales_ex
# 0        8588.47    0.27  Air Import  Michael Scott DDS
# 1        8714.72    0.13  Import Sea        Brady Wells
# 2        1269.03    0.10  Import Sea  Michael Scott DDS
# 3        7990.44    0.05  Import Sea        Brenda Koch
# 4        9278.62    0.12  Air Export        Brady Wells
# ...          ...     ...         ...                ...
# 1195     5345.27    0.12  Air Import     Patrick Barber
# 1196     8089.90    0.10  Import Sea    Dustin Martinez
# 1197     4276.21    0.08  Import Sea        Brenda Koch
# 1198     1040.14    0.29  Air Import     Patrick Barber
# 1199     3526.62    0.24  Import Sea     Daniel Goodman
#
# [1200 rows x 12 columns]

# %%
df["Gross Margin"] = df["Invoiced Value"] * df["Markup"]

# %%
df
# Out:
#       shipment_number                   Customer        Date        Origin  \
# 0                   1                CarterGroup  2024-06-24        Muscat
# 1                   2   Henderson,BoydandShelton  2024-07-24   Johanesburg
# 2                   3                   ShortLtd  2023-09-03      New York
# 3                   4                 ElliottLtd  2023-10-21         Tokyo
# 4                   5   Waters,ReynoldsandHoward  2023-04-10     Barcelona
# ...               ...                        ...         ...           ...
# 1195             1196       OmniTech Fabrication  2023-08-20   Los Angeles
# 1196             1197  StellarWave Manufacturing  2024-07-21       Chicago
# 1197             1198        QuantumEcho Foundry  2023-11-17       Chicago
# 1198             1199             Simmons-Turner  2023-07-04  Buenos Aires
# 1199             1200    Klein,RobinsonandMiller  2023-09-29       Chicago
#
#      Destination  Weight (kgs)  Volume (cubic meters)  Invoiced Value  \
# 0      Barcelona          1565                   2.44        10907.36
# 1      Barcelona          3359                   1.89         9847.63
# 2      Barcelona          1688                   1.40         1395.93
# 3      Barcelona           190                   2.31         8389.96
# 4     Casablanca           437                   1.13        10392.05
# ...          ...           ...                    ...             ...
# 1195   Barcelona          2603                   6.92         5986.70
# 1196   Barcelona           586                   6.23         8898.89
# 1197   Barcelona          3712                   6.61         4618.31
# 1198   Barcelona          2258                   5.92         1341.78
# 1199   Barcelona           417                   3.03         4373.01
#
#       Cost Value  Markup  Department           sales_ex  Gross Margin
# 0        8588.47    0.27  Air Import  Michael Scott DDS     2944.9872
# 1        8714.72    0.13  Import Sea        Brady Wells     1280.1919
# 2        1269.03    0.10  Import Sea  Michael Scott DDS      139.5930
# 3        7990.44    0.05  Import Sea        Brenda Koch      419.4980
# 4        9278.62    0.12  Air Export        Brady Wells     1247.0460
# ...          ...     ...         ...                ...           ...
# 1195     5345.27    0.12  Air Import     Patrick Barber      718.4040
# 1196     8089.90    0.10  Import Sea    Dustin Martinez      889.8890
# 1197     4276.21    0.08  Import Sea        Brenda Koch      369.4648
# 1198     1040.14    0.29  Air Import     Patrick Barber      389.1162
# 1199     3526.62    0.24  Import Sea     Daniel Goodman     1049.5224
#
# [1200 rows x 13 columns]

# %%
margen_clientes = df[['Customer', 'Gross Margin']].groupby(['Customer']).sum()

# %%
margen_df = margen_clientes.head(10).reset_index()

# %%
margen_df
# Out:
#                            Customer  Gross Margin
# 0              AeroNext Engineering    23997.8346
# 1            Allen,WilliamsandWhite    28676.9947
# 2                  ApexFusion Works    13043.8136
# 3  Ascendia SteelworksMartin-Holden    20709.3720
# 4                       Bass-Bolton     9936.9029
# 5         Bennett,VillegasandFowler    13747.7769
# 6                 BlueHorizon Steel    20504.6300
# 7             BrightMinds Machining    13272.6602
# 8                       CarterGroup    30192.9984
# 9         Chandler,TurnerandHouston    23088.6084

# %%
dictionary = [{margen_df.columns[0]: row[0], margen_df.columns[1]: row[1]} for row in margen_df.itertuples(index=False, name=None)]

# %%
dictionary
# Out:
# [{'Customer': 'AeroNext Engineering', 'Gross Margin': 23997.8346},
#  {'Customer': 'Allen,WilliamsandWhite', 'Gross Margin': 28676.9947},
#  {'Customer': 'ApexFusion Works', 'Gross Margin': 13043.8136},
#  {'Customer': 'Ascendia SteelworksMartin-Holden', 'Gross Margin': 20709.372},
#  {'Customer': 'Bass-Bolton', 'Gross Margin': 9936.902900000001},
#  {'Customer': 'Bennett,VillegasandFowler', 'Gross Margin': 13747.7769},
#  {'Customer': 'BlueHorizon Steel', 'Gross Margin': 20504.63},
#  {'Customer': 'BrightMinds Machining', 'Gross Margin': 13272.6602},
#  {'Customer': 'CarterGroup', 'Gross Margin': 30192.9984},
#  {'Customer': 'Chandler,TurnerandHouston', 'Gross Margin': 23088.6084}]

# %%
layout = [
    # Editor item is positioned in coordinates x=0 and y=0,
    # and takes 6/12 columns and has a height of 3.
    dashboard.Item("editor", 0, 1, 6, 3),
    # Chart item is positioned in coordinates x=6 and y=0,
    # and takes 6/12 columns and has a height of 3.
    dashboard.Item("chart", 6, 1, 6, 3),
    # Media item is positioned in coordinates
    # x=0 and y=3, and takes 6/12 columns and has a height of 4.
    dashboard.Item("media", 0, 2, 12, 4),
]
# Create a frame to display elements.

with elements("demo"):

    # Create a new dashboard with the layout specified above.
    #
    # draggableHandle is a CSS query selector to define the draggable part of each dashboard item.
    # Here, elements with a 'draggable' class name will be draggable.
    #
    # For more information on available parameters for dashboard grid:
    # https://github.com/react-grid-layout/react-grid-layout#grid-layout-props
    # https://github.com/react-grid-layout/react-grid-layout#responsive-grid-layout-props

    with dashboard.Grid(layout, draggableHandle=".draggable"):

        # First card, the code editor.
        #
        # We use the 'key' parameter to identify the correct dashboard item.
        #
        # To make card's content automatically fill the height available, we will use CSS flexbox.
        # sx is a parameter available with every Material UI widget to define CSS attributes.
        #
        # For more information regarding Card, flexbox and sx:
        # https://mui.com/components/cards/
        # https://mui.com/system/flexbox/
        # https://mui.com/system/the-sx-prop/
        # We will use the same flexbox configuration as the first card to
        # auto adjust the content height.
        


        with mui.Card(key="editor", sx={"display": "flex", "flexDirection": "column"}):

            # To make this header draggable, we just need to set its classname to 'draggable',
            # as defined above in dashboard.Grid's draggableHandle.

            mui.CardHeader(title="Net Profit Margin per Department", className="draggable")

            # Like above, we want to make our content grow and shrink as the user resizes the card,
            # by setting flex to 1 and minHeight to 0.

            with mui.CardContent(sx={"flex": 1, "minHeight": 0}):

                # For more information regarding other available Nivo charts:
                # https://nivo.rocks/

                nivo.Bar(
                    data=dictionary,
                    keys=["Gross Margin"],
                    indexBy="country",
                    margin={"top": 10, "right": 50, "bottom": 50, "left": 160},
                    padding=0.3,
                    layout="horizontal",
                    groupMode="grouped",
                    valueScale={"type": "linear"},
                    indexScale={"type": "band", "round": True},
                    valueFormat=" >+$,~r",
                    colors={"scheme": "nivo"},
                    colorBy="indexValue",
                    defs=[
                        {
                            "id": "dots",
                            "type": "patternDots",
                            "background": "inherit",
                            "color": "#38bcb2",
                            "size": 4,
                            "padding": 1,
                            "stagger": True,
                        },
                        {
                            "id": "lines",
                            "type": "patternLines",
                            "background": "inherit",
                            "color": "#eed312",
                            "rotation": -45,
                            "lineWidth": 6,
                            "spacing": 10,
                        },
                    ],
                    fill=[
                        {"match": {"id": "fries"}, "id": "dots"},
                        {"match": {"id": "sandwich"}, "id": "lines"},
                    ],
                    borderColor={"from": "color", "modifiers": [["darker", 1.6]]},
                    axisTop=None,
                    axisRight=None,
                    axisBottom={
                        "tickSize": 5,
                        "tickPadding": 5,
                        "tickRotation": 51,
                        "legend": "",
                        "legendPosition": "middle",
                        "legendOffset": 32,
                        "truncateTickAt": 0,
                    },
                    axisLeft={
                        "tickSize": 5,
                        "tickPadding": 5,
                        "tickRotation": 0,
                        "legend": "Gross Margin",
                        "legendPosition": "middle",
                        "legendOffset": -150, #POSISION DE LA LEGENDA
                        "truncateTickAt": 0,
                    },
                    enableLabel=False,
                    labelSkipWidth=12,
                    labelSkipHeight=12,
                    labelTextColor="#ffffff",
                    legends=[
],
                    role="application",
                    ariaLabel="Nivo bar chart demo",
                    barAriaLabel=lambda e: f"{e['id']}: {e['formattedValue']} in country: {e['indexValue']}",
                )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 4
#       1 layout = [
#       2     # Editor item is positioned in coordinates x=0 and y=0,
#       3     # and takes 6/12 columns and has a height of 3.
# ----> 4     dashboard.Item("editor", 0, 1, 6, 3),
#       5     # Chart item is positioned in coordinates x=6 and y=0,
#       6     # and takes 6/12 columns and has a height of 3.
#       7     dashboard.Item("chart", 6, 1, 6, 3),
#       8     # Media item is positioned in coordinates
#       9     # x=0 and y=3, and takes 6/12 columns and has a height of 4.
#      10     dashboard.Item("media", 0, 2, 12, 4),
#      11 ]
#      12 # Create a frame to display elements.
#      14 with elements("demo"):
#      15
#      16     # Create a new dashboard with the layout specified above.
#    (...)
#      22     # https://github.com/react-grid-layout/react-grid-layout#grid-layout-props
#      23     # https://github.com/react-grid-layout/react-grid-layout#responsive-grid-layout-props
#
# NameError: name 'dashboard' is not defined
